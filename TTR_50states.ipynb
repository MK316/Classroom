# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Classroom/blob/main/TTR_50states.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📖 Engpro Week13 (5/26, Tuesday)
#
# ## #️⃣ Todo list:
# Names of US states
# Drama titles

# %% [markdown]
# ---
# ## 1. Introduction to TTS (Text-to-Speech)
# ---

# %%
# Check current working directory:
# %pwd
# Out:
# '/content'

# %%
#@markdown 🚩 {gTTS} package installation and import
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %%
#@markdown 🚩 Making a function { tts ( _text_to_say_) }:
def tts(mytext):

#Install gTTS
# !pip install gTTS
# from gtts import gTTS
# from IPython.display import Audio

  text_to_say = mytext

# Step ⓵ Language to choose:
  language_to_choose = "en" #@param ["en", "fr","ko",'es']
  # lang = language_to_choose

  print("Play language accent: %s"%language_to_choose)
  language = language_to_choose

# gTTS
  gtts_object = gTTS(text = text_to_say,
                     lang = language,
                    slow = False)
  
# #@markdown Step ③: Create the audio file (.wav) to play:
  gtts_object.save("mytext.wav")

# # Output
  return Audio("mytext.wav")

# %% [markdown]
#  1. Alabama.
#  2. Alaska.
#  3. Arizona.
#  4. Arkansas.
#  5. California.
#  6. Colorado.
#  7. Connecticut.
#  8. Delaware.
#  9. Florida.
#  10. Georgia.
#  11. Hawaii.
#  12. Idaho.
#  13. Illinois.
#  14. Indiana.
#  15. Iowa.
#  16. Kansas.
#  17. Kentucky.
#  18. Louisiana.
#  19. Maine.
#  20. Maryland.
#  21. Massachusetts.
#  22. Michigan.
#  23. Minnesota.
#  24. Mississippi.
#  25. Missouri.
#  26. Montana.
#  27. Nebraska.
#  28. Nevada.
#  29. New Hampshire.
#  30. New Jersey.
#  31. New Mexico.
#  32. New York.
#  33. North Carolina.
#  34. North Dakota.
#  35. Ohio.
#  36. Oklahoma.
#  37. Oregon.
#  38. Pennsylvania.
#  39. Rhode Island.
#  40. South Carolina.
#  41. South Dakota.
#  42. Tennessee.
#  43. Texas.
#  44. Utah.
#  45. Vermont.
#  46. Virginia.
#  47. Washington.
#  48. West Virginia.
#  49. Wisconsin.
#  50. Wyoming.
#
#  This is the end.

# %%
#@markdown 🚩 Type text to say
text_to_say = input()
# Out:
#  1. Alabama.  2. Alaska.  3. Arizona.  4. Arkansas.  5. California.  6. Colorado.  7. Connecticut.  8. Delaware.  9. Florida.  10. Georgia.  11. Hawaii.  12. Idaho.  13. Illinois.  14. Indiana.  15. Iowa.  16. Kansas.  17. Kentucky.  18. Louisiana.  19. Maine.  20. Maryland.  21. Massachusetts.  22. Michigan.  23. Minnesota.  24. Mississippi.  25. Missouri.  26. Montana.  27. Nebraska.  28. Nevada.  29. New Hampshire.  30. New Jersey.  31. New Mexico.  32. New York.  33. North Carolina.  34. North Dakota.  35. Ohio.  36. Oklahoma.  37. Oregon.  38. Pennsylvania.  39. Rhode Island.  40. South Carolina.  41. South Dakota.  42. Tennessee.  43. Texas.  44. Utah.  45. Vermont.  46. Virginia.  47. Washington.  48. West Virginia.  49. Wisconsin.  50. Wyoming.   This is the end.

# %%
#@markdown 🚩 Output: Text to Speech (audio)
tts(text_to_say)
# Out:
# Play language accent: en
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Drama titles
#
#
# 1. The X-files.
# 2. 24 hours.
# 3. Crime Scene Investigation, CSI New York, CSI Miami, CSI Las Vegas.
# 4. NCIS, Naval Criminal Investigative Service.
# 5. NCIS Los Angeles.
# 6. NCIS New Orleans.
# 7. Bones.
# 8. Law and Order, Special Victims Unit.
# 9. Law and Order, Criminal Intent.
# 10. Doctor House.
# 11. Nip tuck.
# 12. Hawaii Five-O.
# 13. White Collar.
# 14. Medium.
# 15. The mentalist.
# 16. Criminal Minds.
# 17. Glee.
# 18. Dexter.
# 19. Person of interest.
# 20. Lost.
# 21. The good wife.
# 22. How I met your mother.
# 23. Prison break.
# 24. Walking dead.
# 25. News room.
# 26. The Simpsons.
# 27. Super natural.
# 28. Modern family.
# 29. Game of thrones.

# %%
text_to_say = input()
tts(text_to_say)
